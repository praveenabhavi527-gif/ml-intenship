# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/diabetcsv.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
l1=list(df.columns)
print(l1)
# Out:
# ['preg', 'plas', 'pres', 'skin', 'insu', 'mass', 'pedi', 'age', 'class']

# %%
df=pd.read_csv("/content/drive/MyDrive/diabetcsv.csv")
df2=df.copy()
df2.loc[2:5,'SEMI']=None
df2.head(7)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class  SEMI
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive   NaN
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative   NaN
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive  None
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative  None
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive  None
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative  None
# 6     3    78    50    32    88  31.0  0.248   26  tested_positive   NaN

# %%
df2.isnull().head(7)
# Out:
#     preg   plas   pres   skin   insu   mass   pedi    age  class  SEMI
# 0  False  False  False  False  False  False  False  False  False  True
# 1  False  False  False  False  False  False  False  False  False  True
# 2  False  False  False  False  False  False  False  False  False  True
# 3  False  False  False  False  False  False  False  False  False  True
# 4  False  False  False  False  False  False  False  False  False  True
# 5  False  False  False  False  False  False  False  False  False  True
# 6  False  False  False  False  False  False  False  False  False  True

# %%
print(df2.isnull().sum())
# Out:
# preg       0
# plas       0
# pres       0
# skin       0
# insu       0
# mass       0
# pedi       0
# age        0
# class      0
# SEMI     768
# dtype: int64
