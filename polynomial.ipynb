# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Salary Data.csv')

# %%
X = dataset.iloc[:, 0:1].values
y = dataset.iloc[:, 1].values

# %%
nan_rows_mask=np.isnan(X).any(axis=1)
X_cleaned=X[~nan_rows_mask]
X_poly=poly.fit_transform(X_cleaned)

# %%
y_raw_salary=dataset.iloc[:, 5].values
y_cleaned_salary=y_raw_salary[~nan_rows_mask]
model = LinearRegression()
model.fit(X_poly, y_cleaned_salary)
model.fit(X_poly,y_cleaned_salary)
# Out:
# LinearRegression()

# %%
plt.scatter(X_cleaned,y_cleaned_salary,color='red',label='Actual Data')

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))

plt.plot(
    X_grid,
    model.predict(poly.transform(X_grid)),
    color='blue',
    label='Polynomial Regression Curve'
)

plt.title('Polynomial Regression')
plt.xlabel('Experience / Level')
plt.ylabel('Salary')
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-277085768.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)
