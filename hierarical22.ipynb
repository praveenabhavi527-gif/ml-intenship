# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.preprocessing import StandardScaler

# %%
file_path = "/content/drive/MyDrive/internet_usage.csv"
df = pd.read_csv(file_path)

# %%
numeric_data = df.select_dtypes(include=['int64', 'float64'])

# %%
numeric_cols_to_process=df.columns[2:]
df_numeric_converted=df[numeric_cols_to_process].apply(pd.to_numeric, errors='coerce')
numeric_data_clean=df_numeric_converted.fillna(df_numeric_converted.mean())
scaled_data=scaler.fit_transform(numeric_data_clean)

# %%
linked = linkage(scaled_data, method='ward')

plt.figure(figsize=(12, 6))
dendrogram(
    linked,
    orientation='top',
    distance_sort='descending',
    show_leaf_counts=True
)

plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Data Points")
plt.ylabel("Euclidean Distance")
plt.show()
